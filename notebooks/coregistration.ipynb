# %% [markdown]
# # Use `bash` scripts to coregister the DEMs

# %%
# !bash ../bash_scripts/coregistration_k13_wsyr1.sh
# Out:
# dem_align.py ../data/dems/k13_results/wsyr1/k13_20201109_lidar.tif ../data/dems/k13_results/wsyr1/k13_20201109_sfm.tif
#
# Reference: ../data/dems/k13_results/wsyr1/k13_20201109_lidar.tif
# Source: ../data/dems/k13_results/wsyr1/k13_20201109_sfm.tif
# Mode: nuth
# Output: ../data/dems/k13_results/wsyr1/k13_20201109_sfm_dem_align/k13_20201109_sfm_k13_20201109_lidar
#
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000054
# Extent: [4988.80494140625, 5014.01310546875, 5001.94494140625, 5097.78310546875]
# Projection: '+proj=utm +zone=10 +datum=WGS84 +units=m +no_defs'
# Resampling alg: cubic
#
# 1 of 2: ../data/dems/k13_results/wsyr1/k13_20201109_lidar.tif
# 2 of 2: [memory]
#
# Reference DEM res: 0.01
# Source DEM res: 0.01
# Resolution for coreg: mean (0.01 m)
#
# *** Iteration 1 ***
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000083
# Extent: [4988.80494140625, 5014.01310546875, 5001.94494140625, 5097.78310546875]
# ...

# %%
# !bash ../bash_scripts/coregistration_k13_dsyr1.sh
# Out:
# dem_align.py ../data/dems/k13_results/dsyr1/k13_20210604_lidar.tif ../data/dems/k13_results/dsyr1/k13_20210604_sfm.tif
#
# Reference: ../data/dems/k13_results/dsyr1/k13_20210604_lidar.tif
# Source: ../data/dems/k13_results/dsyr1/k13_20210604_sfm.tif
# Mode: nuth
# Output: ../data/dems/k13_results/dsyr1/k13_20210604_sfm_dem_align/k13_20210604_sfm_k13_20210604_lidar
#
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000068
# Extent: [4988.80779296875, 5014.00998046875, 5001.94779296875, 5097.78998046875]
# Projection: '+proj=utm +zone=10 +datum=WGS84 +units=m +no_defs'
# Resampling alg: cubic
#
# 1 of 2: ../data/dems/k13_results/dsyr1/k13_20210604_lidar.tif
# 2 of 2: [memory]
#
# Reference DEM res: 0.01
# Source DEM res: 0.01
# Resolution for coreg: mean (0.01 m)
#
# *** Iteration 1 ***
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000083
# Extent: [4988.80779296875, 5014.00998046875, 5001.94779296875, 5097.78998046875]
# ...

# %%
# !bash ../bash_scripts/coregistration_k13_wsyr2.sh
# Out:
# dem_align.py ../data/dems/k13_results/wsyr2/k13_20211007_lidar.tif ../data/dems/k13_results/wsyr2/k13_20211007_sfm.tif
#
# Reference: ../data/dems/k13_results/wsyr2/k13_20211007_lidar.tif
# Source: ../data/dems/k13_results/wsyr2/k13_20211007_sfm.tif
# Mode: nuth
# Output: ../data/dems/k13_results/wsyr2/k13_20211007_sfm_dem_align/k13_20211007_sfm_k13_20211007_lidar
#
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000054
# Extent: [4988.80375, 5014.01294921875, 5001.94375, 5097.78294921875]
# Projection: '+proj=utm +zone=10 +datum=WGS84 +units=m +no_defs'
# Resampling alg: cubic
#
# 1 of 2: ../data/dems/k13_results/wsyr2/k13_20211007_lidar.tif
# 2 of 2: [memory]
#
# Reference DEM res: 0.01
# Source DEM res: 0.01
# Resolution for coreg: mean (0.01 m)
#
# *** Iteration 1 ***
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000083
# Extent: [4988.80375, 5014.01294921875, 5001.94375, 5097.78294921875]
# ...

# %%
# !bash ../bash_scripts/coregistration_m14_wsyr1.sh
# Out:
# dem_align.py ../data/dems/m14_results/wsyr1/m14_20201203_lidar.tif ../data/dems/m14_results/wsyr1/m14_20201203_sfm.tif
#
# Reference: ../data/dems/m14_results/wsyr1/m14_20201203_lidar.tif
# Source: ../data/dems/m14_results/wsyr1/m14_20201203_sfm.tif
# Mode: nuth
# Output: ../data/dems/m14_results/wsyr1/m14_20201203_sfm_dem_align/m14_20201203_sfm_m14_20201203_lidar
#
#
# Warping all inputs to the following:
# Resolution: 0.009999999999999763
# Extent: [4988.3499609375, 5000.6200585937495, 4998.6699609375, 5083.97005859375]
# Projection: '+proj=utm +zone=10 +datum=WGS84 +units=m +no_defs'
# Resampling alg: cubic
#
# 1 of 2: ../data/dems/m14_results/wsyr1/m14_20201203_lidar.tif
# 2 of 2: [memory]
#
# Reference DEM res: 0.01
# Source DEM res: 0.01
# Resolution for coreg: mean (0.01 m)
#
# *** Iteration 1 ***
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000018
# Extent: [4988.3499609375, 5000.6200585937495, 4998.6699609375, 5083.97005859375]
# ...

# %%
# !bash ../bash_scripts/coregistration_m14_dsyr1.sh
# Out:
# dem_align.py ../data/dems/m14_results/dsyr1/m14_20210603_lidar.tif ../data/dems/m14_results/dsyr1/m14_20210603_sfm.tif
#
# Reference: ../data/dems/m14_results/dsyr1/m14_20210603_lidar.tif
# Source: ../data/dems/m14_results/dsyr1/m14_20210603_sfm.tif
# Mode: nuth
# Output: ../data/dems/m14_results/dsyr1/m14_20210603_sfm_dem_align/m14_20210603_sfm_m14_20210603_lidar
#
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000217
# Extent: [4988.3483203125, 5000.6171289062495, 4998.6683203125, 5083.97712890625]
# Projection: '+proj=utm +zone=10 +datum=WGS84 +units=m +no_defs'
# Resampling alg: cubic
#
# 1 of 2: ../data/dems/m14_results/dsyr1/m14_20210603_lidar.tif
# 2 of 2: [memory]
#
# Reference DEM res: 0.01
# Source DEM res: 0.01
# Resolution for coreg: mean (0.01 m)
#
# *** Iteration 1 ***
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000389
# Extent: [4988.3483203125, 5000.6171289062495, 4998.6683203125, 5083.97712890625]
# ...

# %%
# !bash ../bash_scripts/coregistration_m14_wsyr2.sh
# Out:
# dem_align.py ../data/dems/m14_results/wsyr2/m14_20220309_lidar.tif ../data/dems/m14_results/wsyr2/m14_20220309_sfm.tif
#
# Reference: ../data/dems/m14_results/wsyr2/m14_20220309_lidar.tif
# Source: ../data/dems/m14_results/wsyr2/m14_20220309_sfm.tif
# Mode: nuth
# Output: ../data/dems/m14_results/wsyr2/m14_20220309_sfm_dem_align/m14_20220309_sfm_m14_20220309_lidar
#
#
# Warping all inputs to the following:
# Resolution: 0.00999999999999988
# Extent: [4988.34548828125, 5000.6169140625, 4998.67548828125, 5083.9769140625]
# Projection: '+proj=utm +zone=10 +datum=WGS84 +units=m +no_defs'
# Resampling alg: cubic
#
# 1 of 2: ../data/dems/m14_results/wsyr2/m14_20220309_lidar.tif
# 2 of 2: [memory]
#
# Reference DEM res: 0.01
# Source DEM res: 0.01
# Resolution for coreg: mean (0.01 m)
#
# *** Iteration 1 ***
#
# Warping all inputs to the following:
# Resolution: 0.010000000000000044
# Extent: [4988.34548828125, 5000.6169140625, 4998.67548828125, 5083.9769140625]
# ...
